# %% [markdown]
# <a href="https://colab.research.google.com/github/jmhuer/Fall2021MusicResearch/blob/main/HarmonyReductionAndDecompostion/metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Usage Demo :

# %%
# !rm -r python3_midi/
# !sudo apt-get install libasound2-dev swig
# !pip3 install git+https://github.com/vishnubob/python-midi@feature/python3
# !pip install git+https://github.com/vishnubob/python-midi@feature/python3
# !pip install pretty_midi
# !git clone https://github.com/jmhuer/mgeval
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libasound2-dev is already the newest version (1.1.3-5ubuntu0.6).
# Suggested packages:
#   swig-doc swig-examples swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig swig3.0
# 0 upgraded, 2 newly installed, 0 to remove and 39 not upgraded.
# Need to get 1,100 kB of archives.
# After this operation, 5,822 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig3.0 amd64 3.0.12-1 [1,094 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig amd64 3.0.12-1 [6,460 B]
# Fetched 1,100 kB in 1s (1,214 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package swig3.0.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../swig3.0_3.0.12-1_amd64.deb ...
# Unpacking swig3.0 (3.0.12-1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_3.0.12-1_amd64.deb ...
# Unpacking swig (3.0.12-1) ...
# Setting up swig3.0 (3.0.12-1) ...
# Setting up swig (3.0.12-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting git+https://github.com/vishnubob/python-midi@feature/python3
#   Cloning https://github.com/vishnubob/python-midi (to revision feature/python3) to /tmp/pip-req-build-pc8epv05
#   Running command git clone -q https://github.com/vishnubob/python-midi /tmp/pip-req-build-pc8epv05
#   Running command git checkout -b feature/python3 --track origin/feature/python3
#   Switched to a new branch 'feature/python3'
#   Branch 'feature/python3' set up to track remote branch 'feature/python3' from 'origin'.
# Building wheels for collected packages: midi
#   Building wheel for midi (setup.py) ... done
#   Created wheel for midi: filename=midi-0.2.3-cp37-cp37m-linux_x86_64.whl size=281244 sha256=d0a9cbac9769e2661acba2cc17691a8b2d7a39506e76e7b6ae9bdcacb19e2146
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ghxw8z8k/wheels/31/42/68/b7b99ce373ff4c2ef140f869eeb0b3c5297c64a2ac16b5dc88
# Successfully built midi
# Installing collected packages: midi
# Successfully installed midi-0.2.3
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 5.3 MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pretty_midi) (1.21.5)
# Collecting mido>=1.1.16
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 7.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pretty_midi) (1.15.0)
# Building wheels for collected packages: pretty-midi
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591955 sha256=3d0ce7cc14f5ae691664bf40388437589fc8d82c18981bb88aade31d55175b80
#   Stored in directory: /root/.cache/pip/wheels/ad/74/7c/a06473ca8dcb63efb98c1e67667ce39d52100f837835ea18fa
# Successfully built pretty-midi
# Installing collected packages: mido, pretty-midi
# Successfully installed mido-1.2.10 pretty-midi-0.2.9
# Cloning into 'mgeval'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 140 (delta 0), reused 2 (delta 0), pack-reused 137
# Receiving objects: 100% (140/140), 138.41 KiB | 3.84 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
import midi
import glob
import numpy as np
import pretty_midi
import seaborn as sns
import matplotlib.pyplot as plt
from mgeval.mgeval import core, utils
from sklearn.model_selection import LeaveOneOut

# %%
# !unzip autoharmonyresults.zip
# !unzip autoharmonyresults/rules/"*.zip" -d autoharmonyresults/rules/
# !unzip autoharmonyresults/kwtalifetime/"*.zip" -d autoharmonyresults/kwtalifetime/
# !unzip autoharmonyresults/ordinary/"*.zip" -d autoharmonyresults/ordinary/
# !unzip autoharmonyresults/kwta/"*.zip" -d autoharmonyresults/kwta/
# !unzip autoharmonyresults/justae/"*.zip" -d autoharmonyresults/justae/


# # !unzip /content/1.3kwta.zip
# # !unzip /content/1.5kwta.zip
# # !unzip /content/autoharmonyresults.zip
# # !unzip /content/.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_15.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_11.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_6.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_3.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_35.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_6.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_21.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_32.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_19.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_1.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_1.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_2.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_8.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_38.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_3.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_31.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_36.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_14.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_0.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_8.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_2.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_24.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_16.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_0.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_17.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_27.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_20.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_14.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_3.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_24.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_18.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_20.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_39.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_19.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_5.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_27.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_28.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_6.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_18.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_12.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_18.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_12.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_19.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_23.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_3.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_26.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_21.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_35.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_22.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_23.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_36.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_16.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_39.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_2.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_13.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_18.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_20.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_21.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_8.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_29.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_2.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_31.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_31.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_39.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_34.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_36.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_23.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_3.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_5.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_24.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_15.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_25.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_26.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_10.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_20.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_21.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_33.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_34.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_33.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_8.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_6.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_7.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_22.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_9.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_22.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_32.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_16.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_24.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_4.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_19.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_16.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_9.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_10.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_9.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_26.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_33.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_28.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_15.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_39.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_7.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_27.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_12.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_11.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_4.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_28.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_22.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_8.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_23.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_39.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_9.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_37.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_12.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_7.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_4.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_11.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_21.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_4.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_1.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_13.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_14.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_33.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_34.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_16.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_35.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_37.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_12.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_20.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_4.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_35.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_7.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_5.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_28.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_5.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_6.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_15.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_19.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_25.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_1.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_30.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_0.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_5.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_36.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_8.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_21.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_27.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_2.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_34.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_23.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_16.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_17.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_26.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_39.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_22.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_6.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_38.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_33.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_1.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_9.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_24.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_18.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_29.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_7.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_27.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_15.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_28.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_27.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_5.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/42_30.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_38.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_34.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_16.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_32.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/45_34.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_1.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_38.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_12.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_36.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_31.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_28.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/46_20.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/43_39.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/47_14.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_13.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/48_25.mid
#   inflating: autoharmonyresults/ordinary/1.9kwta/44_14.mid
#
# Archive:  autoharmonyresults/ordinary/1.3kwta.zip
#    creating: autoharmonyresults/ordinary/1.3kwta/
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_2.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_22.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_39.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_11.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_24.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_10.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_19.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_12.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_9.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_32.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_5.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_2.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_25.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_30.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_28.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_9.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_0.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_36.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_6.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_23.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_25.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_34.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_38.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_23.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_34.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_36.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_23.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_33.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_15.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_7.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_24.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_15.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_6.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_28.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_16.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_18.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_35.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_27.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_22.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_38.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_7.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_32.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_12.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_29.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_14.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_2.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_0.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_16.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_32.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_8.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_27.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_32.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_26.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_27.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_37.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_3.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_5.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_33.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_16.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_1.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_13.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_6.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_39.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_33.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_12.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_11.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_14.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_29.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_26.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_8.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_16.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_10.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_0.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_30.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_20.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_39.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_36.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_7.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_28.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_3.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_21.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_34.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_27.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_3.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_5.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_35.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_20.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_12.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_13.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_27.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_29.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_38.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_3.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_21.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_37.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_2.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_1.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_6.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_15.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_1.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_28.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_33.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_37.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_1.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_16.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_2.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_4.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_23.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_4.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_6.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_14.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_19.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_29.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_25.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_31.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_5.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_20.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_9.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_22.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_19.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_13.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_18.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_17.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_23.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_13.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_11.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_3.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_33.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_4.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_14.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_35.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_38.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_0.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_0.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_25.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_21.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_26.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_12.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_0.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_10.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_38.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_10.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_5.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_12.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_9.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_35.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_7.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_16.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_28.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_11.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_13.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_4.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_15.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_4.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_24.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_7.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_18.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_29.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_39.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_12.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_21.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_19.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_33.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_20.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_34.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_26.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_36.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_3.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_36.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_18.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_30.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_8.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_24.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_11.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_24.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_8.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_24.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_34.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_32.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_30.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_23.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_21.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_35.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_31.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_34.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_25.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_28.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_39.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_10.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_27.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_5.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_2.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_20.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_33.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_7.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_22.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_9.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_37.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_14.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_19.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_30.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_22.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_5.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_34.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_21.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_16.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_30.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_4.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_10.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_23.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_17.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_26.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_31.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_39.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_14.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_25.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_18.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_8.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_20.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_32.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_25.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_24.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_32.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_37.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_22.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_4.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_9.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_9.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_15.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_26.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_15.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_7.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_11.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_11.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_21.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_13.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_22.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_39.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_37.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_19.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_10.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_31.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_14.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_17.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_29.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_38.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_31.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_17.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_17.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_17.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_18.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_1.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_38.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_31.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_30.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_18.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_19.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_27.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/30_6.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_1.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/32_3.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_37.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_2.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_26.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_29.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_35.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_8.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_36.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/28_0.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_13.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_31.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_20.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/31_28.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_8.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_15.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_17.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/34_1.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_35.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/33_6.mid
#   inflating: autoharmonyresults/ordinary/1.3kwta/29_36.mid
#
# Archive:  autoharmonyresults/ordinary/0.3kwta.zip
#    creating: autoharmonyresults/ordinary/0.3kwta/
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_29.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_8.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_0.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_17.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_34.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_24.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_1.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_8.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_19.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_25.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_31.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_28.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_2.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_24.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_38.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_1.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_33.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_20.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_26.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_1.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_27.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_33.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_24.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_11.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_31.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_39.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_17.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_9.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_34.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_34.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_17.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_5.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_1.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_25.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_7.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_27.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_28.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_5.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_8.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_13.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_38.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_4.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_5.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_7.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_26.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_17.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_15.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_23.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_20.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_31.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_35.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_26.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_6.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_7.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_22.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_15.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_9.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_2.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_12.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_2.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_16.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_20.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_9.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_36.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_31.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_31.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_39.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_7.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_17.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_24.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_13.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_21.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_20.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_30.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_0.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_27.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_8.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_12.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_0.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_26.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_23.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_29.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_20.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_4.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_2.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_38.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_7.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_33.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_16.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_16.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_11.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_23.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_30.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_21.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_3.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_33.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_11.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_28.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_17.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_13.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_32.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_3.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_9.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_37.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_21.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_30.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_22.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_23.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_18.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_2.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_12.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_1.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_5.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_39.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_1.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_24.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_6.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_34.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_27.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_23.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_14.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_10.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_9.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_11.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_29.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_32.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_36.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_35.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_37.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_29.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_19.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_31.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_8.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_13.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_19.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_19.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_5.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_24.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_2.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_3.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_10.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_1.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_12.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_28.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_25.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_20.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_39.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_14.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_0.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_15.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_8.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_37.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_7.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_30.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_10.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_18.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_10.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_35.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_36.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_30.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_22.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_25.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_12.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_13.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_26.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_13.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_36.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_10.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_17.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_10.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_7.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_6.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_37.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_33.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_36.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_21.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_33.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_29.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_0.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_28.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_25.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_34.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_11.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_4.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_32.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_16.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_21.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_6.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_38.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_3.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_37.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_28.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_4.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_38.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_14.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_14.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_30.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_18.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_39.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_18.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_18.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_15.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_15.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_32.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_19.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_21.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_2.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_3.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_34.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_14.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_35.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_20.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_10.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_28.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_9.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_3.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_27.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_19.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_12.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_6.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_0.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_12.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_6.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_36.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_5.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_22.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_18.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_22.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_32.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_39.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_22.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_23.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_32.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_37.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_32.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_15.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_9.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_6.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_18.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_37.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_27.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_29.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_14.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_35.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_4.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_23.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_29.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_4.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_35.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_4.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_21.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_16.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_11.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_24.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_16.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_11.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_36.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_30.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_26.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_22.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_38.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_33.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_25.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_25.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_26.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/3_15.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_8.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_3.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_34.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_5.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_0.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_27.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/5_13.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/4_16.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_39.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/6_31.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/0_19.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_14.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/1_38.mid
#   inflating: autoharmonyresults/ordinary/0.3kwta/2_35.mid
#
# Archive:  autoharmonyresults/ordinary/1kwta.zip
#    creating: autoharmonyresults/ordinary/1kwta/
#   inflating: autoharmonyresults/ordinary/1kwta/21_5.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_9.mid
#   inflating: autoharmonyresults/ordinary/1kwta/21_30.mid
#   inflating: autoharmonyresults/ordinary/1kwta/24_28.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_37.mid
#   inflating: autoharmonyresults/ordinary/1kwta/26_28.mid
#   inflating: autoharmonyresults/ordinary/1kwta/21_29.mid
#   inflating: autoharmonyresults/ordinary/1kwta/23_21.mid
#   inflating: autoharmonyresults/ordinary/1kwta/24_9.mid
#   inflating: autoharmonyresults/ordinary/1kwta/21_14.mid
#   inflating: autoharmonyresults/ordinary/1kwta/23_34.mid
#   inflating: autoharmonyresults/ordinary/1kwta/23_12.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_27.mid
#   inflating: autoharmonyresults/ordinary/1kwta/22_17.mid
#   inflating: autoharmonyresults/ordinary/1kwta/22_31.mid
#   inflating: autoharmonyresults/ordinary/1kwta/24_6.mid
#   inflating: autoharmonyresults/ordinary/1kwta/26_13.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_1.mid
#   inflating: autoharmonyresults/ordinary/1kwta/25_15.mid
#   inflating: autoharmonyresults/ordinary/1kwta/23_22.mid
#   inflating: autoharmonyresults/ordinary/1kwta/24_18.mid
#   inflating: autoharmonyresults/ordinary/1kwta/24_23.mid
#   inflating: autoharmonyresults/ordinary/1kwta/23_0.mid
#   inflating: autoharmonyresults/ordinary/1kwta/26_12.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_10.mid
#   inflating: autoharmonyresults/ordinary/1kwta/22_1.mid
#   inflating: autoharmonyresults/ordinary/1kwta/26_36.mid
#   inflating: autoharmonyresults/ordinary/1kwta/23_15.mid
#   inflating: autoharmonyresults/ordinary/1kwta/24_38.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_7.mid
#   inflating: autoharmonyresults/ordinary/1kwta/22_20.mid
#   inflating: autoharmonyresults/ordinary/1kwta/21_17.mid
#   inflating: autoharmonyresults/ordinary/1kwta/22_27.mid
#   inflating: autoharmonyresults/ordinary/1kwta/25_13.mid
#   inflating: autoharmonyresults/ordinary/1kwta/21_25.mid
#   inflating: autoharmonyresults/ordinary/1kwta/21_22.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_23.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_34.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_4.mid
#   inflating: autoharmonyresults/ordinary/1kwta/22_35.mid
#   inflating: autoharmonyresults/ordinary/1kwta/25_23.mid
#   inflating: autoharmonyresults/ordinary/1kwta/21_10.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_11.mid
#   inflating: autoharmonyresults/ordinary/1kwta/23_33.mid
#   inflating: autoharmonyresults/ordinary/1kwta/27_14.mid
# ...
#   inflating: autoharmonyresults/justae/0.5kwta/11_24.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_33.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_11.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_37.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_20.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_37.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_1.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_16.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_7.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_29.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_6.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_39.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_22.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_18.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_28.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_4.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_17.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_28.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_30.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_26.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_23.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_12.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_34.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_37.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_25.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_33.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_15.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_3.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_24.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_0.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_4.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_12.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_34.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_20.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_20.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_7.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_28.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_26.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_2.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_23.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_27.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_14.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_30.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_13.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_10.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_36.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_16.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_31.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_19.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_2.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_12.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_17.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_16.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_33.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_25.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_2.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_7.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_6.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_29.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_37.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_18.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_38.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_32.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_25.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_19.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_30.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_26.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_4.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_10.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_34.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_12.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_31.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_36.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_15.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_8.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_11.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_13.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_29.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_30.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_20.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_31.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_7.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_18.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_2.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_7.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_22.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_35.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_2.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_17.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_31.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_6.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_34.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_35.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_34.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_38.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_39.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_34.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_9.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_4.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_13.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_12.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_36.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_5.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_7.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_24.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_1.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_13.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_14.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_31.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_24.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_17.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_27.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_25.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_31.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_1.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_6.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_12.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_11.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_9.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_21.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_33.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_15.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_12.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_2.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_28.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_35.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_37.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_30.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_36.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_39.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_36.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_2.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_25.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_5.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_33.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_28.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_34.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_0.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_30.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_39.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_31.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_15.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_35.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_13.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_19.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_26.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_1.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_15.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_21.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_30.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_0.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_19.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_16.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_14.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_13.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_36.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_3.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_38.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_29.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_27.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_10.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_1.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_23.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_8.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_19.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_5.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_5.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_0.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_24.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_8.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_32.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_11.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_39.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_21.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_22.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_5.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_22.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_37.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_21.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_4.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_14.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_18.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_3.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_8.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_4.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_5.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_25.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_10.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_23.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_16.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_23.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_3.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_23.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_27.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_13.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_32.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_32.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_9.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_3.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_3.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_19.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_25.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_20.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_35.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_32.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_35.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_18.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_32.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_4.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_17.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_20.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_1.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_23.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_15.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_33.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_6.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_8.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_22.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_14.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_8.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_36.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_22.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_35.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_11.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_26.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_18.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_38.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_38.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_24.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_39.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_37.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_21.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_38.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_8.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_21.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_9.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_0.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_7.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_18.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_32.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_16.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_24.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_0.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_9.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_3.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_28.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_14.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_11.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_26.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_15.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_20.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_38.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_17.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_27.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_1.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_17.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_6.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_0.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_19.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_21.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_14.mid
#   inflating: autoharmonyresults/justae/0.5kwta/13_29.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_6.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_10.mid
#   inflating: autoharmonyresults/justae/0.5kwta/9_9.mid
#   inflating: autoharmonyresults/justae/0.5kwta/8_33.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_29.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_5.mid
#   inflating: autoharmonyresults/justae/0.5kwta/10_28.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_10.mid
#   inflating: autoharmonyresults/justae/0.5kwta/11_29.mid
#   inflating: autoharmonyresults/justae/0.5kwta/12_16.mid
#   inflating: autoharmonyresults/justae/0.5kwta/7_10.mid
#
# 7 archives were successfully processed.

# %% [markdown]
# ## Absolute measurement: statistic analysis

# %% [markdown]
# Assign dataset path

# %%
# !mv /content/autoharmonyresults/ordinary/0.3kwta/* /content/ordinary/
# !mv /content/autoharmonyresults/ordinary/0.5kwta/* /content/ordinary/
# !mv /content/autoharmonyresults/ordinary/0.7kwta/* /content/ordinary/
# !mv /content/autoharmonyresults/ordinary/1.3kwta/* /content/ordinary/
# !mv /content/autoharmonyresults/ordinary/1.5kwta/* /content/ordinary/
# !mv /content/autoharmonyresults/ordinary/1.9kwta/* /content/ordinary/


# !mv /content/autoharmonyresults/rules/0.3rules/* /content/rules/
# !mv /content/autoharmonyresults/rules/0.5rules/* /content/rules/
# !mv /content/autoharmonyresults/rules/0.7rules/* /content/rules/
# !mv /content/autoharmonyresults/rules/1.3rules/* /content/rules/
# !mv /content/autoharmonyresults/rules/1.5rules/* /content/rules/
# !mv /content/autoharmonyresults/rules/1.9rules/* /content/rules/

# %% [markdown]
# #Eval features

# %%
feature1 = "avg_IOI"

# %% [markdown]
# original data

# %%
set0 = glob.glob('/content/autoharmonyresults/kwtalifetime/1kwta/*')
# set0 = glob.glob('/content/original/*')

num_samples = len(set0)
set_eval0 = {feature1:np.zeros((num_samples,1))}
print(num_samples)

metrics_list = list(set_eval0.keys())
for i in range(0, num_samples):
    feature = core.extract_feature(set0[i])
    set_eval0[metrics_list[0]][i] = getattr(core.metrics(), metrics_list[0])(feature)
# Out:
# 280

# %%
set1 = glob.glob('/content/autoharmonyresults/justae/1.5kwta/*')
# set1 = glob.glob('/content/kwta/*')

num_samples = len(set1)
set_eval1 = {feature1:np.zeros((num_samples,1))}
print(num_samples)

metrics_list = list(set_eval1.keys())
for i in range(0, num_samples):
    feature = core.extract_feature(set1[i])
    set_eval1[metrics_list[0]][i] = getattr(core.metrics(), metrics_list[0])(feature)
# Out:
# 280

# %% [markdown]
# repeat for second dataset

# %%
set2 = glob.glob('/content/autoharmonyresults/rules/1.9rules/*')
# set2 = glob.glob('/content/rules/*')

num_samples = len(set2)
set_eval2 = {feature1:np.zeros((num_samples,1))}
print(num_samples)


metrics_list = list(set_eval2.keys())
for i in range(0, num_samples):
    feature = core.extract_feature(set2[i])
    set_eval2[metrics_list[0]][i] = getattr(core.metrics(), metrics_list[0])(feature)
# Out:
# 280

# %% [markdown]
# repeat for thirds dataset

# %%
set3 = glob.glob('/content/autoharmonyresults/kwtalifetime/1.5kwta/*')
# set3 = glob.glob('/content/kwtalifetime/*')

num_samples = len(set3)
set_eval3 = {feature1:np.zeros((num_samples,1))}
print(num_samples)

metrics_list = list(set_eval3.keys())
for i in range(0, num_samples):
    feature = core.extract_feature(set3[i])
    set_eval3[metrics_list[0]][i] = getattr(core.metrics(), metrics_list[0])(feature)
# Out:
# 280

# %% [markdown]
# repeat for fourth dataset

# %%
set4 = glob.glob('/content/autoharmonyresults/ordinary/1.5kwta/*')
# set4 = glob.glob('/content/ordinary/*')

num_samples = len(set4)
set_eval4 = {feature1:np.zeros((num_samples,1))}
print(num_samples)

metrics_list = list(set_eval4.keys())
for i in range(0, num_samples):
    feature = core.extract_feature(set4[i])
    set_eval4[metrics_list[0]][i] = getattr(core.metrics(), metrics_list[0])(feature)
# Out:
# 280

# %% [markdown]
# #statistic analysis: absolute measurement

# %%
print(len(metrics_list))

for i in range(0, len(metrics_list)):
    print(metrics_list[i] + ':')
    
    print('------------------------')
    print(' demo_set0')
    print('  mean: ', np.mean(set_eval0[metrics_list[i]], axis=0))
    print('  std: ', np.std(set_eval0[metrics_list[i]], axis=0))

    print('------------------------')
    print(' demo_set1')
    print('  mean: ', np.mean(set_eval1[metrics_list[i]], axis=0))
    print('  std: ', np.std(set_eval1[metrics_list[i]], axis=0))

    print('------------------------')
    print(' demo_set2')
    print('  mean: ', np.mean(set_eval2[metrics_list[i]], axis=0))
    print('  std: ', np.std(set_eval2[metrics_list[i]], axis=0))

    print('------------------------')
    print(' demo_set3')
    print('  mean: ', np.mean(set_eval3[metrics_list[i]], axis=0))
    print('  std: ', np.std(set_eval3[metrics_list[i]], axis=0))

    print('------------------------')
    print(' demo_set4')
    print('  mean: ', np.mean(set_eval4[metrics_list[i]], axis=0))
    print('  std: ', np.std(set_eval4[metrics_list[i]], axis=0))
# Out:
# 1
# avg_IOI:
# ------------------------
#  demo_set0
#   mean:  [0.18523854]
#   std:  [0.07877771]
# ------------------------
#  demo_set1
#   mean:  [0.1108616]
#   std:  [0.04582908]
# ------------------------
#  demo_set2
#   mean:  [0.12543436]
#   std:  [0.05425331]
# ------------------------
#  demo_set3
#   mean:  [0.11932334]
#   std:  [0.04676239]
# ------------------------
#  demo_set4
#   mean:  [0.11740172]
#   std:  [0.04743483]

# %% [markdown]
# ## Relative measurement: generalizes the result among features with various dimensions

# %% [markdown]
# the features are sum- marized to
# - the intra-set distances
# - the difference of intra-set and inter-set distances.

# %% [markdown]
# #exhaustive cross-validation for intra-set distances measurement

# %% [markdown]
# #requires same number samples per folder

# %%
loo = LeaveOneOut()
loo.get_n_splits(np.arange(num_samples))
set0_intra = np.zeros((num_samples, len(metrics_list), num_samples-1))
set1_intra = np.zeros((num_samples, len(metrics_list), num_samples-1))
set2_intra = np.zeros((num_samples, len(metrics_list), num_samples-1))
set3_intra = np.zeros((num_samples, len(metrics_list), num_samples-1))
set4_intra = np.zeros((num_samples, len(metrics_list), num_samples-1))

for i in range(len(metrics_list)):
    for train_index, test_index in loo.split(np.arange(num_samples)):
        # print(train_index)
        set0_intra[test_index[0]][i] = utils.c_dist(set_eval0[metrics_list[i]][test_index], set_eval0[metrics_list[i]][train_index])
        set1_intra[test_index[0]][i] = utils.c_dist(set_eval1[metrics_list[i]][test_index], set_eval1[metrics_list[i]][train_index])
        set2_intra[test_index[0]][i] = utils.c_dist(set_eval2[metrics_list[i]][test_index], set_eval2[metrics_list[i]][train_index])
        set3_intra[test_index[0]][i] = utils.c_dist(set_eval3[metrics_list[i]][test_index], set_eval3[metrics_list[i]][train_index])
        set4_intra[test_index[0]][i] = utils.c_dist(set_eval4[metrics_list[i]][test_index], set_eval4[metrics_list[i]][train_index])

# %% [markdown]
# exhaustive cross-validation for inter-set distances measurement

# %% [markdown]
# #sets_inter

# %%
loo = LeaveOneOut()
loo.get_n_splits(np.arange(num_samples))
sets_inter0 = np.zeros((num_samples, len(metrics_list), num_samples))
sets_inter1 = np.zeros((num_samples, len(metrics_list), num_samples))
sets_inter2 = np.zeros((num_samples, len(metrics_list), num_samples))
sets_inter3 = np.zeros((num_samples, len(metrics_list), num_samples))

for i in range(len(metrics_list)):
    for train_index, test_index in loo.split(np.arange(num_samples)):
        # print(test_index)
        sets_inter0[test_index[0]][i] = utils.c_dist(set_eval0[metrics_list[i]][test_index], set_eval1[metrics_list[i]])
        sets_inter1[test_index[0]][i] = utils.c_dist(set_eval0[metrics_list[i]][test_index], set_eval2[metrics_list[i]])
        sets_inter2[test_index[0]][i] = utils.c_dist(set_eval0[metrics_list[i]][test_index], set_eval3[metrics_list[i]])
        sets_inter3[test_index[0]][i] = utils.c_dist(set_eval0[metrics_list[i]][test_index], set_eval4[metrics_list[i]])

# %%
#mean
print("mean")
print(np.mean(plot_set0_intra[i]))
print(np.mean(plot_set1_intra[i]))
print(np.mean(plot_set2_intra[i]))
print(np.mean(plot_set3_intra[i]), "\n")
#std
print("std")
print(np.std(plot_set0_intra[i]))
print(np.std(plot_set1_intra[i]))
print(np.std(plot_set2_intra[i]))
print(np.std(plot_set3_intra[i]))
# Out:
# mean
# 7.5340757808499745
# 7.707757296466974
# 8.290117767537122
# 7.649411162314388
#
# std
# 5.658989208475377
# 6.013330152014928
# 6.272936174578832
# 5.837803940730007

# %% [markdown]
# visualization of intra-set and inter-set distances
#
#
#
# *   inter-set we compare 1 sample from harmny transofmotaion data with all others from original data
# *   inter set is between the same dataset

# %%
plt.rcParams.update({'font.size': 14})


plot_set0_intra = np.transpose(set0_intra,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_set1_intra = np.transpose(set1_intra,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_set2_intra = np.transpose(set2_intra,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_set3_intra = np.transpose(set3_intra,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_set4_intra = np.transpose(set4_intra,(1, 0, 2)).reshape(len(metrics_list), -1)

plot_sets_inter0 = np.transpose(sets_inter0,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_sets_inter1 = np.transpose(sets_inter1,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_sets_inter2 = np.transpose(sets_inter2,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_sets_inter3 = np.transpose(sets_inter3,(1, 0, 2)).reshape(len(metrics_list), -1)

for i in range(0,len(metrics_list)):
    sns.kdeplot(plot_set0_intra[i], label='intra original', linestyle='--')
    # sns.kdeplot(plot_set1_intra[i], label='lstmae')
    # sns.kdeplot(plot_set2_intra[i], label='rules')
    # # # sns.kdeplot(backup[i], label='1.3')
    # sns.kdeplot(plot_set3_intra[i], label='kwtalifetime')
    # sns.kdeplot(plot_set4_intra[i], label='kwta')
    sns.kdeplot(plot_sets_inter0[i], label='inter AE')
    sns.kdeplot(plot_sets_inter1[i], label='inter rules')
    sns.kdeplot(plot_sets_inter2[i], label='inter kwtalifetime')
    sns.kdeplot(plot_sets_inter3[i], label='inter kwta')
    
    plt.legend()
    plt.title("Average IOI")
    plt.xlabel('Euclidean distance')
    plt.show()

# %% [markdown]
# the difference of intra-set and inter-set distances.

# %% [markdown]
# #Kullback–Leibler Divergence

# %%
for i in range(0, len(metrics_list)):
    print(metrics_list[i] + ':')
    print('------------------------')
    print(' demo_set1')
    print('  Kullback–Leibler divergence:',utils.kl_dist(plot_set0_intra[i], plot_sets_inter0[i]))
    print('  Overlap area:', utils.overlap_area(plot_set0_intra[i], plot_sets_inter0[i]))
    
    print(' demo_set2')
    print('  Kullback–Leibler divergence:',utils.kl_dist(plot_set0_intra[i], plot_sets_inter1[i]))
    print('  Overlap area:', utils.overlap_area(plot_set0_intra[i], plot_sets_inter1[i]))

    print(' demo_set3')
    print('  Kullback–Leibler divergence:',utils.kl_dist(plot_set0_intra[i], plot_sets_inter2[i]))
    print('  Overlap area:', utils.overlap_area(plot_set0_intra[i], plot_sets_inter2[i]))

    print(' demo_set4')
    print('  Kullback–Leibler divergence:',utils.kl_dist(plot_set0_intra[i], plot_sets_inter3[i]))
    print('  Overlap area:', utils.overlap_area(plot_set0_intra[i], plot_sets_inter3[i]))
# Out:
# avg_IOI:
# ------------------------
#  demo_set1
#   Kullback–Leibler divergence: 0.017602665368263035
# /content/mgeval/mgeval/utils.py:18: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   return integrate.quad(lambda x: min(pdf_A(x), pdf_B(x)), np.min((np.min(A), np.min(B))), np.max((np.max(A), np.max(B))))[0]
#   Overlap area: 0.8807512496526221
#  demo_set2

# %%
# import time 

# for i in range(1000):
#   time.sleep(10)
